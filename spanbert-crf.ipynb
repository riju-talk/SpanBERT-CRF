# %% [markdown]
# # SpanBERT-CRF — Fine-tuning on SQuAD v2.0 (QA) and CoNLL-2003 (NER)
#
# **Standalone notebook.** Everything it needs — the CRF layer, both model heads, the
# data pipeline and the training loop — is defined inline, so it runs on Colab with no
# dependency on the project's `src/` package.
#
# A **linear-chain CRF sits on top of SpanBERT for both tasks**:
#
# | Task | Dataset | Tag set the CRF decodes |
# |------|---------|-------------------------|
# | Question Answering | SQuAD v2.0 (subset) | `O` / `B-ANS` / `I-ANS` over the sequence — Viterbi gives one contiguous answer span (or all-`O` = unanswerable) |
# | Named Entity Recognition | CoNLL-2003 (subset) | `O` / `B-`,`I-` × {PER, ORG, LOC, MISC} |
#
# > Trains in a few minutes on a single T4 with the default subset sizes. Scale
# > `QA_TRAIN_SIZE` / `NER_TRAIN_SIZE` and `EPOCHS` up for real results.

# %% [markdown]
# ## 0. Setup

# %%
# Colab: uncomment to install
# !pip install -q torch transformers datasets seqeval

import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer, get_linear_schedule_with_warmup
from tqdm.auto import tqdm

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MODEL_NAME = 'SpanBERT/spanbert-base-cased'

# --- knobs: bump these up for a serious run ---
QA_TRAIN_SIZE, QA_EVAL_SIZE = 3000, 800
NER_TRAIN_SIZE, NER_EVAL_SIZE = 3000, 800
EPOCHS = 2
BATCH_SIZE = 16
LR = 3e-5
QA_MAX_LEN = 320
NER_MAX_LEN = 128

print('device:', DEVICE)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %% [markdown]
# ## 1. Linear-chain CRF
#
# Batch-first CRF with the standard forward algorithm for the log-partition function
# and Viterbi decoding. `forward` returns the mean negative log-likelihood; `decode`
# returns the best tag sequence.

# %%
class CRF(nn.Module):
    def __init__(self, num_tags: int):
        super().__init__()
        self.num_tags = num_tags
        self.transitions = nn.Parameter(torch.empty(num_tags, num_tags).uniform_(-0.1, 0.1))
        self.start_transitions = nn.Parameter(torch.empty(num_tags).uniform_(-0.1, 0.1))
        self.end_transitions = nn.Parameter(torch.empty(num_tags).uniform_(-0.1, 0.1))

    def forward(self, emissions, tags, mask):
        """emissions (B,L,T), tags (B,L) long, mask (B,L) {0,1}. Returns scalar NLL."""
        emissions = emissions.transpose(0, 1)   # (L,B,T)
        tags = tags.transpose(0, 1)             # (L,B)
        mask = mask.transpose(0, 1).float()     # (L,B)
        seq_len, batch_size, _ = emissions.shape

        # gold-path score
        score = self.start_transitions[tags[0]] + emissions[0].gather(1, tags[0].unsqueeze(1)).squeeze(1)
        for i in range(1, seq_len):
            score = score + (self.transitions[tags[i - 1], tags[i]]
                             + emissions[i].gather(1, tags[i].unsqueeze(1)).squeeze(1)) * mask[i]
        seq_ends = mask.long().sum(0) - 1
        last_tags = tags.gather(0, seq_ends.unsqueeze(0)).squeeze(0)
        score = score + self.end_transitions[last_tags]

        # log partition (forward algorithm)
        alpha = self.start_transitions + emissions[0]                 # (B,T)
        for i in range(1, seq_len):
            inner = (alpha.unsqueeze(2)                               # (B,T,1)
                     + self.transitions.unsqueeze(0)                  # (1,T,T)
                     + emissions[i].unsqueeze(1))                     # (B,1,T)
            alpha = torch.where(mask[i].bool().unsqueeze(1),
                                torch.logsumexp(inner, dim=1), alpha)
        log_z = torch.logsumexp(alpha + self.end_transitions, dim=1)  # (B,)
        return (log_z - score).mean()

    @torch.no_grad()
    def decode(self, emissions, mask):
        emissions = emissions.transpose(0, 1)
        mask = mask.transpose(0, 1).bool()
        seq_len, batch_size, _ = emissions.shape

        score = self.start_transitions + emissions[0]
        history = []
        for i in range(1, seq_len):
            nxt = score.unsqueeze(2) + self.transitions + emissions[i].unsqueeze(1)
            nxt, idx = nxt.max(dim=1)
            score = torch.where(mask[i].unsqueeze(1), nxt, score)
            history.append(idx)
        score = score + self.end_transitions

        lengths = mask.long().sum(0)
        best = []
        for b in range(batch_size):
            last = score[b].argmax().item()
            seq = [last]
            for idx in reversed(history[: lengths[b] - 1]):
                last = idx[b][last].item()
                seq.append(last)
            seq.reverse()
            seq += [0] * (seq_len - len(seq))
            best.append(seq)
        return torch.tensor(best, device=emissions.device)

# %% [markdown]
# ## 2. SpanBERT-CRF model heads
#
# Both heads share the pattern *SpanBERT encoder → linear emissions → CRF*.
# For QA the answer span is expressed as a 3-tag BIO sequence.

# %%
QA_O, QA_B, QA_I = 0, 1, 2

def spans_to_bio(start_positions, end_positions, seq_len):
    """(start, end) token indices -> (B, L) BIO tensor. start==0 => unanswerable => all-O."""
    device = start_positions.device
    pos = torch.arange(seq_len, device=device).unsqueeze(0)
    starts = start_positions.clamp(0, seq_len - 1).unsqueeze(1)
    ends = end_positions.clamp(0, seq_len - 1).unsqueeze(1)
    answerable = (start_positions > 0).unsqueeze(1)
    bio = torch.full((start_positions.size(0), seq_len), QA_O, dtype=torch.long, device=device)
    bio = torch.where((pos >= starts) & (pos <= ends) & answerable, torch.full_like(bio, QA_I), bio)
    bio = torch.where((pos == starts) & answerable, torch.full_like(bio, QA_B), bio)
    return bio


class SpanBERTCRFForQA(nn.Module):
    def __init__(self, model_name=MODEL_NAME):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name).float()
        hidden = self.encoder.config.hidden_size
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(hidden, 3)
        self.crf = CRF(num_tags=3)

    def forward(self, input_ids, attention_mask, token_type_ids=None,
                start_positions=None, end_positions=None):
        h = self.encoder(input_ids=input_ids, attention_mask=attention_mask,
                         token_type_ids=token_type_ids).last_hidden_state
        emissions = self.classifier(self.dropout(h))          # (B,L,3)
        loss = None
        if start_positions is not None:
            bio = spans_to_bio(start_positions, end_positions, input_ids.size(1))
            loss = self.crf(emissions, bio, attention_mask)
        return loss, emissions

    @torch.no_grad()
    def predict_spans(self, input_ids, attention_mask, token_type_ids=None):
        _, emissions = self(input_ids, attention_mask, token_type_ids)
        return self.crf.decode(emissions, attention_mask)     # (B,L) in {O,B,I}


class SpanBERTCRFForNER(nn.Module):
    def __init__(self, num_tags, model_name=MODEL_NAME):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name).float()
        hidden = self.encoder.config.hidden_size
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(hidden, num_tags)
        self.crf = CRF(num_tags=num_tags)

    def forward(self, input_ids, attention_mask, token_type_ids=None, labels=None):
        h = self.encoder(input_ids=input_ids, attention_mask=attention_mask,
                         token_type_ids=token_type_ids).last_hidden_state
        emissions = self.classifier(self.dropout(h))
        loss = None
        if labels is not None:
            crf_labels = labels.clone()
            ignore = crf_labels == -100
            crf_labels[ignore] = 0
            crf_mask = attention_mask.clone()
            crf_mask[ignore] = 0
            crf_mask[:, 0] = 1                                # first step must stay active
            loss = self.crf(emissions, crf_labels, crf_mask)
        return loss, emissions

    @torch.no_grad()
    def predict(self, input_ids, attention_mask, token_type_ids=None):
        _, emissions = self(input_ids, attention_mask, token_type_ids)
        return self.crf.decode(emissions, attention_mask)

# %% [markdown]
# ## 3. Training loop
#
# One generic loop for both tasks — AdamW, linear war-mup schedule, gradient clipping.

# %%
def train_model(model, train_loader, val_loader, epochs=EPOCHS, lr=LR):
    model.to(DEVICE)
    no_decay = ('bias', 'LayerNorm.weight')
    grouped = [
        {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
         'weight_decay': 0.01},
        {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
         'weight_decay': 0.0},
    ]
    opt = torch.optim.AdamW(grouped, lr=lr)
    total = len(train_loader) * epochs
    sched = get_linear_schedule_with_warmup(opt, int(0.1 * total), total)

    for epoch in range(1, epochs + 1):
        model.train()
        running = 0.0
        bar = tqdm(train_loader, desc=f'epoch {epoch}/{epochs}')
        for batch in bar:
            batch = {k: v.to(DEVICE) for k, v in batch.items()}
            loss = model(**batch)[0]
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step(); sched.step(); opt.zero_grad()
            running += loss.item()
            bar.set_postfix(loss=f'{loss.item():.3f}')
        print(f'  epoch {epoch}: train loss {running / len(train_loader):.4f}')

        model.eval()
        val = 0.0
        with torch.no_grad():
            for batch in val_loader:
                batch = {k: v.to(DEVICE) for k, v in batch.items()}
                val += model(**batch)[0].item()
        print(f'  epoch {epoch}: val   loss {val / len(val_loader):.4f}')
    return model

# %% [markdown]
# ---
# # Part A — Question Answering on SQuAD v2.0

# %%
from datasets import load_dataset

squad = load_dataset('rajpurkar/squad_v2')
squad_train = squad['train'].shuffle(seed=SEED).select(range(QA_TRAIN_SIZE))
squad_val = squad['validation'].shuffle(seed=SEED).select(range(QA_EVAL_SIZE))
print(squad_train, squad_val, sep='\n')

# %%
class QADataset(Dataset):
    def __init__(self, hf_split, tokenizer, max_len=QA_MAX_LEN):
        self.data, self.tok, self.max_len = hf_split, tokenizer, max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        ex = self.data[i]
        enc = self.tok(ex['question'], ex['context'], truncation='only_second',
                       max_length=self.max_len, padding='max_length',
                       return_offsets_mapping=True, return_token_type_ids=True,
                       return_tensors='pt')
        offsets = enc.pop('offset_mapping')[0]
        seq_ids = enc.sequence_ids(0)
        item = {k: v[0] for k, v in enc.items()}

        answers = ex['answers']
        if len(answers['text']) == 0:                     # unanswerable
            item['start_positions'] = torch.tensor(0)
            item['end_positions'] = torch.tensor(0)
            return item

        a_start = answers['answer_start'][0]
        a_end = a_start + len(answers['text'][0])
        ctx_tokens = [j for j, s in enumerate(seq_ids) if s == 1]
        lo, hi = ctx_tokens[0], ctx_tokens[-1]
        if not (offsets[lo][0] <= a_start and offsets[hi][1] >= a_end):
            item['start_positions'] = torch.tensor(0)     # answer truncated away
            item['end_positions'] = torch.tensor(0)
            return item
        s = lo
        while s <= hi and offsets[s][0] <= a_start:
            s += 1
        e = hi
        while e >= lo and offsets[e][1] >= a_end:
            e -= 1
        item['start_positions'] = torch.tensor(s - 1)
        item['end_positions'] = torch.tensor(e + 1)
        return item


qa_train_loader = DataLoader(QADataset(squad_train, tokenizer), batch_size=BATCH_SIZE, shuffle=True)
qa_val_loader = DataLoader(QADataset(squad_val, tokenizer), batch_size=BATCH_SIZE)
batch = next(iter(qa_train_loader))
print({k: tuple(v.shape) for k, v in batch.items()})

# %%
qa_model = SpanBERTCRFForQA()
qa_model = train_model(qa_model, qa_train_loader, qa_val_loader)

# %% [markdown]
# ### Evaluate — Exact Match / token-F1
#
# Viterbi-decode the BIO tags, take the first `B-ANS …` run as the predicted span,
# and score against every gold answer (empty string for unanswerable).

# %%
import re, string, collections

def normalize(s):
    s = s.lower()
    s = ''.join(ch if ch not in set(string.punctuation) else ' ' for ch in s)
    s = re.sub(r'\b(a|an|the)\b', ' ', s)
    return ' '.join(s.split())

def f1(pred, gold):
    p, g = normalize(pred).split(), normalize(gold).split()
    if not p or not g:
        return float(p == g)
    common = collections.Counter(p) & collections.Counter(g)
    same = sum(common.values())
    if same == 0:
        return 0.0
    prec, rec = same / len(p), same / len(g)
    return 2 * prec * rec / (prec + rec)

def bio_to_span(tag_row, input_ids):
    idx = (tag_row == QA_B).nonzero().flatten()
    if len(idx) == 0:
        return ''
    s = idx[0].item()
    e = s
    while e + 1 < len(tag_row) and tag_row[e + 1].item() == QA_I:
        e += 1
    return tokenizer.decode(input_ids[s:e + 1], skip_special_tokens=True).strip()

qa_model.eval()
em_tot = f1_tot = n = 0
with torch.no_grad():
    for i in tqdm(range(len(squad_val)), desc='qa eval'):
        ex = squad_val[i]
        enc = tokenizer(ex['question'], ex['context'], truncation='only_second',
                        max_length=QA_MAX_LEN, padding='max_length',
                        return_token_type_ids=True, return_tensors='pt').to(DEVICE)
        tags = qa_model.predict_spans(enc['input_ids'], enc['attention_mask'],
                                      enc.get('token_type_ids'))[0].cpu()
        pred = bio_to_span(tags, enc['input_ids'][0].cpu())
        golds = ex['answers']['text'] or ['']
        em_tot += max(float(normalize(pred) == normalize(g)) for g in golds)
        f1_tot += max(f1(pred, g) for g in golds)
        n += 1
print(f'\nSQuAD v2 subset ({n} ex)  EM={100*em_tot/n:.2f}  F1={100*f1_tot/n:.2f}')

# %% [markdown]
# ---
# # Part B — Named Entity Recognition on CoNLL-2003

# %%
# parquet export -> no dataset script needed
conll = load_dataset('eriktks/conll2003', revision='refs/convert/parquet')
TAG_NAMES = conll['train'].features['ner_tags'].feature.names
NUM_NER_TAGS = len(TAG_NAMES)
id2tag = dict(enumerate(TAG_NAMES))
print(TAG_NAMES)

conll_train = conll['train'].shuffle(seed=SEED).select(range(NER_TRAIN_SIZE))
conll_val = conll['validation'].shuffle(seed=SEED).select(range(NER_EVAL_SIZE))

# %%
class NERDataset(Dataset):
    def __init__(self, hf_split, tokenizer, max_len=NER_MAX_LEN):
        self.data, self.tok, self.max_len = hf_split, tokenizer, max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        ex = self.data[i]
        enc = self.tok(ex['tokens'], is_split_into_words=True, truncation=True,
                       max_length=self.max_len, padding='max_length',
                       return_token_type_ids=True, return_tensors='pt')
        word_ids = enc.word_ids(0)
        labels, prev = [], None
        for wid in word_ids:
            if wid is None:
                labels.append(-100)
            elif wid != prev:
                labels.append(ex['ner_tags'][wid])        # label first sub-token only
            else:
                labels.append(-100)
            prev = wid
        item = {k: v[0] for k, v in enc.items()}
        item['labels'] = torch.tensor(labels)
        return item


ner_train_loader = DataLoader(NERDataset(conll_train, tokenizer), batch_size=BATCH_SIZE, shuffle=True)
ner_val_loader = DataLoader(NERDataset(conll_val, tokenizer), batch_size=BATCH_SIZE)
batch = next(iter(ner_train_loader))
print({k: tuple(v.shape) for k, v in batch.items()})

# %%
ner_model = SpanBERTCRFForNER(num_tags=NUM_NER_TAGS)
ner_model = train_model(ner_model, ner_train_loader, ner_val_loader)

# %% [markdown]
# ### Evaluate — entity-level precision / recall / F1

# %%
def spans_from_tags(tag_ids):
    ents, cur, start = set(), None, None
    for i, tid in enumerate(tag_ids):
        tag = id2tag[tid]
        if tag.startswith('B-'):
            if cur:
                ents.add((cur, start, i - 1))
            cur, start = tag[2:], i
        elif tag.startswith('I-') and cur == tag[2:]:
            continue
        else:
            if cur:
                ents.add((cur, start, i - 1))
            cur, start = None, None
    if cur:
        ents.add((cur, start, len(tag_ids) - 1))
    return ents

ner_model.eval()
tp = fp = fn = 0
with torch.no_grad():
    for batch in tqdm(ner_val_loader, desc='ner eval'):
        batch = {k: v.to(DEVICE) for k, v in batch.items()}
        preds = ner_model.predict(batch['input_ids'], batch['attention_mask'],
                                  batch.get('token_type_ids')).cpu()
        for row_pred, row_lab in zip(preds, batch['labels'].cpu()):
            keep = row_lab != -100
            p = spans_from_tags(row_pred[keep].tolist())
            g = spans_from_tags(row_lab[keep].tolist())
            tp += len(p & g); fp += len(p - g); fn += len(g - p)

prec = tp / (tp + fp) if tp + fp else 0.0
rec = tp / (tp + fn) if tp + fn else 0.0
f1_score = 2 * prec * rec / (prec + rec) if prec + rec else 0.0
print(f'\nCoNLL-2003 subset  P={100*prec:.2f}  R={100*rec:.2f}  F1={100*f1_score:.2f}')

# %% [markdown]
# ## Save

# %%
import os
os.makedirs('models', exist_ok=True)
torch.save({'model_state_dict': qa_model.state_dict()}, 'models/spanbert_crf_qa.pt')
torch.save({'model_state_dict': ner_model.state_dict(), 'tag_names': TAG_NAMES},
           'models/spanbert_crf_ner.pt')
print('saved -> models/spanbert_crf_qa.pt, models/spanbert_crf_ner.pt')
