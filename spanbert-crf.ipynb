# %% [markdown]
# # SpanBERT-CRF: QA + NER Training & Evaluation
#
# End-to-end pipelines for SQuAD v2.0 (QA) and CoNLL-2003 (NER).
# Uses the `src` package with optional CRF and PEFT LoRA.

# %%
import torch
from transformers import AutoTokenizer

from src.models import SpanBERTForQA, SpanBERTForNER, apply_lora_to_model
from src.data import load_squad_data, load_conll_ner_data, create_dataloaders
from src.train import Trainer, upload_to_huggingface
from src.metrics import compute_qa_metrics, compute_ner_metrics, compute_span_overlap_metrics
from src.inference import QAInference, NERInference

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

USE_CRF = True
USE_LORA = True
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5050 Laptop GPU

# %% [markdown]
# ---
# # QA Pipeline (SQuAD v2.0)
# ---

# %% [markdown]
# ## QA.1  Load SQuAD v2.0 (15k train / 5k validation)

# %%
qa_train = load_squad_data("train", max_samples=15000)
qa_val = load_squad_data("validation", max_samples=5000)
print(f"QA Train: {len(qa_train)}  QA Val: {len(qa_val)}")
# Out:
# ...
# QA Train: 15000  QA Val: 5000

# %% [markdown]
# ## QA.2  Tokenizer + Dataloaders

# %%
tokenizer = AutoTokenizer.from_pretrained("SpanBERT/spanbert-base-cased")

qa_train_loader, qa_val_loader = create_dataloaders(
    qa_train, qa_val, tokenizer,
    batch_size=16, max_length=384, dataset_type="qa",
)
print(f"QA Train batches: {len(qa_train_loader)}  QA Val batches: {len(qa_val_loader)}")
# Out:
# QA Train batches: 938  QA Val batches: 313

# %% [markdown]
# ## QA.3  Model

# %%
qa_model = SpanBERTForQA(use_crf=USE_CRF, model_name="SpanBERT/spanbert-base-cased")

if USE_LORA:
    qa_model = apply_lora_to_model(qa_model, use_lora=True, r=8, lora_alpha=32)

n_total = sum(p.numel() for p in qa_model.parameters())
n_train = sum(p.numel() for p in qa_model.parameters() if p.requires_grad)
print(f"QA params: {n_total:,} total, {n_train:,} trainable ({100*n_train/n_total:.2f}%)")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: SpanBERT/spanbert-base-cased
# Key                 | Status  |
# --------------------+---------+-
# pooler.dense.weight | MISSING |
# pooler.dense.bias   | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# trainable params: 958,464 || all params: 109,268,736 || trainable%: 0.8772
# QA params: 109,270,290 total, 960,018 trainable (0.88%)

# %% [markdown]
# ## QA.4  Train

# %%
qa_trainer = Trainer(
    model=qa_model, tokenizer=tokenizer, device=device,
    learning_rate=2e-5, num_epochs=3, batch_size=16, use_wandb=False,
)
qa_history = qa_trainer.train(qa_train_loader, qa_val_loader)
# Out:
# Epoch 1/3
# Training: 100%|██████████| 938/938 [15:50<00:00,  1.01s/it, loss=11.0101]
# Average Training Loss: 37.4170
# Validation Metrics: {'val_loss': 10.937063099858099}
#
# Epoch 2/3
# Training: 100%|██████████| 938/938 [16:02<00:00,  1.03s/it, loss=5.4707]
# Average Training Loss: 7.6103
# Validation Metrics: {'val_loss': 6.102959704475281}
#
# Epoch 3/3
# Training: 100%|██████████| 938/938 [15:56<00:00,  1.02s/it, loss=5.7675]
# Average Training Loss: 5.9759
# Validation Metrics: {'val_loss': 5.528016196272244}

# %% [markdown]
# ## QA.5  Evaluate QA

# %%
qa_model.eval()
qa_preds, qa_golds = [], []
pred_starts, pred_ends, true_starts, true_ends = [], [], [], []

with torch.no_grad():
    for batch in qa_val_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        start_logits, end_logits = qa_model(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            token_type_ids=batch.get("token_type_ids"),
        )

        s_idx = start_logits.argmax(dim=-1)
        e_idx = end_logits.argmax(dim=-1)

        pred_starts.append(s_idx.cpu())
        pred_ends.append(e_idx.cpu())
        true_starts.append(batch["start_positions"].cpu())
        true_ends.append(batch["end_positions"].cpu())

        for i in range(batch["input_ids"].size(0)):
            text = tokenizer.decode(batch["input_ids"][i][s_idx[i]:e_idx[i]+1], skip_special_tokens=True)
            qa_preds.append({"id": str(len(qa_preds)), "prediction_text": text})

for ex in qa_val:
    qa_golds.append({"id": str(len(qa_golds)), "answers": [ex["answer_text"]]})

pred_starts = torch.cat(pred_starts)
pred_ends = torch.cat(pred_ends)
true_starts = torch.cat(true_starts)
true_ends = torch.cat(true_ends)

qa_metrics = compute_qa_metrics(qa_preds, qa_golds)
span_metrics = compute_span_overlap_metrics(pred_starts, pred_ends, true_starts, true_ends)

print("=== QA Validation ===")
for k, v in qa_metrics.items():
    print(f"  {k.upper():<15}: {v:.4f}")
for k, v in span_metrics.items():
    print(f"  {k.upper():<20}: {v:.4f}")
# Out:
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]

# %% [markdown]
# ## QA.6  Save QA model

# %%
qa_trainer.save_model("models/spanbert_qa_finetuned.pt")

# %% [markdown]
# ## QA.7  Upload QA to HuggingFace Hub (optional)
#
# Run `huggingface-cli login` first, then uncomment:

# %%
upload_to_huggingface(
     model=qa_model,
     tokenizer=tokenizer,
     repo_id="Phantomcloak19/SpanBERT-CRF",
     task="qa",
)

# %% [markdown]
# ---
# # NER Pipeline (CoNLL-2003)
# ---

# %% [markdown]
# ## NER.1  Load CoNLL-2003 (15k train / 5k validation)

# %%
ner_train_raw, label_map = load_conll_ner_data("train", max_samples=15000)
ner_val_raw, _ = load_conll_ner_data("validation", max_samples=5000)
id2label = {v: k for k, v in label_map.items()}
print(f"NER Train: {len(ner_train_raw)}  NER Val: {len(ner_val_raw)}")
print(f"Labels ({len(label_map)}): {label_map}")

# %% [markdown]
# ## NER.2  Tokenizer + Dataloaders

# %%
ner_train_loader, ner_val_loader = create_dataloaders(
    (ner_train_raw, label_map), (ner_val_raw, label_map), tokenizer,
    batch_size=16, max_length=128, dataset_type="ner",
)
print(f"NER Train batches: {len(ner_train_loader)}  NER Val batches: {len(ner_val_loader)}")

# %% [markdown]
# ## NER.3  Model

# %%
ner_model = SpanBERTForNER(num_ner_tags=len(label_map), use_crf=USE_CRF, model_name="SpanBERT/spanbert-base-cased")

if USE_LORA:
    ner_model = apply_lora_to_model(ner_model, use_lora=True, r=8, lora_alpha=32)

n_total = sum(p.numel() for p in ner_model.parameters())
n_train = sum(p.numel() for p in ner_model.parameters() if p.requires_grad)
print(f"NER params: {n_total:,} total, {n_train:,} trainable ({100*n_train/n_total:.2f}%)")

# %% [markdown]
# ## NER.4  Train

# %%
ner_trainer = Trainer(
    model=ner_model, tokenizer=tokenizer, device=device,
    learning_rate=2e-5, num_epochs=3, batch_size=16, use_wandb=False,
)
ner_history = ner_trainer.train(ner_train_loader, ner_val_loader)

# %% [markdown]
# ## NER.5  Evaluate NER

# %%
ner_model.eval()
ner_pred_tags, ner_true_tags = [], []

with torch.no_grad():
    for batch in ner_val_loader:
        batch = {k: v.to(device) for k, v in batch.items()}
        outputs = ner_model(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
        )

        if USE_CRF:
            tags = outputs[-1]  # decoded tags from CRF.decode()
        else:
            tags = outputs[-1].argmax(dim=-1)

        for i in range(batch["input_ids"].size(0)):
            labels = batch["labels"][i].cpu().tolist()
            pred = tags[i].cpu().tolist()
            valid = [l != -100 for l in labels]
            ner_pred_tags.append([p for p, m in zip(pred, valid) if m])
            ner_true_tags.append([t for t, m in zip(labels, valid) if m])

ner_metrics = compute_ner_metrics(ner_pred_tags, ner_true_tags, id2label)

print("=== NER Validation ===")
for k, v in ner_metrics.items():
    print(f"  {k.upper():<15}: {v:.4f}")

# %% [markdown]
# ## NER.6  Save NER model

# %%
ner_trainer.save_model("models/spanbert_ner_finetuned.pt")

# %% [markdown]
# ## NER.7  Upload NER to HuggingFace Hub (optional)
#
# Run `huggingface-cli login` first, then uncomment:

# %%
# upload_to_huggingface(
#     model=ner_model,
#     tokenizer=tokenizer,
#     repo_id="Phantomcloak19/SpanBERT-CRF-NER",
#     task="ner",
# )
